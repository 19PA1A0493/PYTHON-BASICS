# %% [markdown]
# <a href="https://colab.research.google.com/github/19PA1A0493/PYTHON-BASICS/blob/master/matplot1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
plt.plot()
# Out:
# []

# %%
j=[1,2,3]
h=[11,33,22]
plt.plot(j,h)

# %%
x=(1,2,3)
y=(11,33,44)
plt.plot(x,y,linestyle="--")

# %%
r=np.arange(50)
y=np.random.random(50)
plt.plot(r,y, linestyle="--")

# %%
y=np.arange(30)
x=np.random.random(30)
plt.plot(y,x)

y1=np.arange(30)
x1=np.random.random(30)
plt.plot(y1,x1, linestyle="--")

# %%
t=np.arange(50)
y=np.random.random(50)
plt.plot(t,y,linestyle="--",color="black")


plt.figure()
f=np.arange(30)
j=np.random.random(30)
plt.plot(f,j, linestyle="--")

# %%
p=np.arange(42)
q=np.random.random(42)
plt.scatter(p,q,color="r")

# %%
s=np.arange(23)
v=np.random.random(23)
plt.plot(s,v)
plt.scatter(s,v,marker="*",color="black")

# %%
f=np.arange(56)
plt.hist(f,color="g")
# Out:
# (array([6., 5., 6., 5., 6., 5., 6., 5., 6., 6.]),
#  array([ 0. ,  5.5, 11. , 16.5, 22. , 27.5, 33. , 38.5, 44. , 49.5, 55. ]),
#  <a list of 10 Patch objects>)

# %%
n=np.random.random(12)
plt.hist(n)
# Out:
# (array([3., 2., 1., 2., 0., 0., 0., 0., 3., 1.]),
#  array([0.01214015, 0.10949536, 0.20685056, 0.30420577, 0.40156097,
#         0.49891618, 0.59627138, 0.69362659, 0.79098179, 0.888337  ,
#         0.9856922 ]),
#  <a list of 10 Patch objects>)

# %%
b=np.random.randint(1,30,50)
plt.hist(b)
# Out:
# (array([8., 4., 2., 6., 1., 3., 6., 5., 6., 9.]),
#  array([ 1. ,  3.6,  6.2,  8.8, 11.4, 14. , 16.6, 19.2, 21.8, 24.4, 27. ]),
#  <a list of 10 Patch objects>)

# %%
h=np.random.randint(0,11,50)
print(h)


y=np.linspace(0,20,6)
print(y)

plt.hist(h,y,width=1.5)
# Out:
# [ 0  8  3  8  7  1  3 10  3 10 10  0  5  1  5  7 10  3  1  1  1  1  7  0
#   7  8  7  6  7  7  0  4  1  6  5  9  2  7  1  9  1  2  7  5  9  1  5  2
#   4 10]
# [ 0.  4.  8. 12. 16. 20.]
# (array([21., 18., 11.,  0.,  0.]),
#  array([ 0.,  4.,  8., 12., 16., 20.]),
#  <a list of 5 Patch objects>)

# %%
s,v=plt.subplots()
print(s)
print(v)
v.plot([1,2,3],[1,4,7])
v.plot(np.random.randint(1,20,30))
# Out:
# Figure(432x288)
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
r,g=plt.subplots(nrows=2,ncols=5)
