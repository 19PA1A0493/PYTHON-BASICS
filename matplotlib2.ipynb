# %% [markdown]
# <a href="https://colab.research.google.com/github/19PA1A0493/PYTHON-BASICS/blob/master/matplotlib2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
s=[1,2,3]
v=[11,22,33]
plt.plot(s,v)

# %%
s=np.arange(30)
v=np.random.random(30)
plt.plot(s,v,linestyle="--")

# %%
s=np.arange(20)
v=np.random.random(20)
plt.plot(s,v,linestyle="--")


s1=np.arange(20)
v1=np.random.random(20)
plt.plot(s1,v1,color="r")

# %%
s=np.arange(30)
v=np.random.random(30)
plt.plot(s,v,linestyle="--",color="r")



plt.figure()
s1=np.arange(20)
v1=np.random.random(20)
plt.plot(s1,v1,color="blue")

# %%
f=np.arange(20).reshape(5,4)
g=np.random.random(20)
plt.scatter(f,g)

# %%
s=np.arange(30)
v=np.random.random(30)
plt.plot(s,v)
plt.scatter(s,v,marker="+")

# %%
s=np.random.randint(0,100,25)
plt.hist(s)
# Out:
# (array([4., 2., 0., 1., 2., 5., 0., 3., 4., 4.]),
#  array([ 0. ,  9.7, 19.4, 29.1, 38.8, 48.5, 58.2, 67.9, 77.6, 87.3, 97. ]),
#  <a list of 10 Patch objects>)

# %%
s=np.random.randint(1,20,10)
print(s)

v=np.linspace(1,20,10)
print(v)


plt.scatter(s,v,color="r")
# Out:
# [16 12 17  9  4 17 18 14  4  7]
# [ 1.          3.11111111  5.22222222  7.33333333  9.44444444 11.55555556
#  13.66666667 15.77777778 17.88888889 20.        ]

# %%
s=np.random.randint(1,20,10)
print(s)

v=np.linspace(1,20,10)
print(v)

plt.hist(s,v,width=0.5,color="black")
# Out:
# [ 9 10  7 10  4  3 11  6 18  1]
# [ 1.          3.11111111  5.22222222  7.33333333  9.44444444 11.55555556
#  13.66666667 15.77777778 17.88888889 20.        ]
# (array([2., 1., 2., 1., 3., 0., 0., 0., 1.]),
#  array([ 1.        ,  3.11111111,  5.22222222,  7.33333333,  9.44444444,
#         11.55555556, 13.66666667, 15.77777778, 17.88888889, 20.        ]),
#  <a list of 9 Patch objects>)
